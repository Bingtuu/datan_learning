# %%
import pandas as pd

data = pd.read_csv('datasets\world_happiness_report_2019.csv')
data.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
import pandas_profiling  

# 由于 pandas 已经更新到1.0.1版本，而目前 pandas_profiling 仅支持0.25版本，因此需要待 pandas_profiling 更新后
data.profile_report(title='Titanic Dataset')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-4e7ec31504f1> in <module>
# ----> 1 import pandas_profiling
#       2
#       3 data.profile_report(title='Titanic Dataset')
#
# c:\users\mayn\appdata\local\programs\python\python37\lib\site-packages\pandas_profiling\__init__.py in <module>
#      18 from pandas_profiling.utils.paths import get_config_default, get_config_minimal
#      19 from pandas_profiling.config import config
# ---> 20 from pandas_profiling.controller import pandas_decorator
#      21 from pandas_profiling.model.describe import describe as describe_df
#      22 from pandas_profiling.model.messages import MessageType
#
# c:\users\mayn\appdata\local\programs\python\python37\lib\site-packages\pandas_profiling\controller\pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ...

# %%
pfr = pandas_profiling.ProfileReport(data)
pfr.to_file('report.html')
